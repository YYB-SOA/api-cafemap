# %%
import requests 
import json

# # 超連結
# url = 'https://www.google.com.tw/maps/preview/review/listentitiesreviews?authuser=0&hl=zh-TW&gl=tw&pb=!1m2!1y3776327198877621511!2y7549128770825705490!2m1!2i10!3e2!4m5!3b1!4b1!5b1!6b1!7b1!5m2!1sbktRY7DaOsyioATKoo3oBg!7e81'
# # 發送get請求
# text = requests.get(url).text
# # 取代掉特殊字元，這個字元是為了資訊安全而設定的喔。
# pretext = ')]}\''
# text = text.replace(pretext,'')
# # 把字串讀取成json
# soup = json.loads(text)

# # 取出包含留言的List 。
# conlist = soup[2]

# k = 0

# # 逐筆抓出
# for i in conlist:
#     k += 1
#     print("username:"+str(i[0][1]))
#     print("time:"+str(i[1]))
#     print("comment:"+str(i[3]))
#     print("--------{}---------".format(k))
# Out:
# username:Aki Chen
# time:2 天前
# comment:非常好吃的牛肉燴飯，家人都愛吃，可以提早打去預定，謝謝結帳的小姐，服務態度優質，很快讓我拿回家享用！
# --------1---------
# username:Hsing-Chien Huang (Argen)
# time:5 天前
# comment:沙茶味不會很重，微辣。對不喜歡一般沙茶料理太鹹的我，覺得這家味道還真好吃。
# --------2---------
# username:何立緯
# time:1 週前
# comment:本次消費沙茶牛肉燴飯、沙茶牛肉拌麵、牛肉湯、豬肝湯
#
# 沙茶牛肉燴飯有一種特殊溫潤的香氣，牛肉片份量不少，口感滑嫩芡汁不膩，是好吃的牛肉燴飯。但我個人是完全沒吃出沙茶味，如果是為了想吃到沙茶味而來的應該會相當失望。
#
# 牛肉拌面味道就差不少。由於麵體是類似烏龍麵的粗圓麵，無法像米飯這樣吸附湯汁和香氣。在原本芡汁口味比較清淡的狀況下就顯得相當無味。
#
# 牛肉湯的牛肉雖然滑嫩但份量偏少且過於破碎，吃起來很不過癮。豬肝湯湯面略濁且豬肝過老過硬沒有鮮味，並不推薦。
#
# 如果不是為了沙茶而去的，燴飯相當不錯，但其他的料理就不太推。
# --------3---------
# username:黃世文
# time:2 週前
# comment:None
# --------4---------
# username:林星宇
# time:3 週前
# comment:芹菜  燴飯加了芹菜  口味偏淡
# --------5---------
# username:廖思蓓
# time:3 週前
# comment:None
# --------6---------
# username:Lee Ken-Ching
# time:1 個月前
# comment:這家也是口袋名單，加肉份量夠
# --------7---------
# username:秋賢楊
# time:1 個月前
# comment:None
# --------8---------
# username:寶鋅
# time:1 個月前
# ...

# %%
import time
! pip install selenium
! pip install bs4
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
from selenium.webdriver.chrome.service import Service
import subprocess
import sys
# 開啟瀏覽器視窗(Chrome)
# 方法一：執行前需開啟chromedriver.exe且與執行檔在同一個工作目錄
store_name = sys.argv[1]
store_name

########
chromedriver_path = "lib/chromedriver.exe"
service = Service(chromedriver_path)
process = subprocess.Popen(['chromedriver', '--port=9515'], stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
# Wait for the process to start
service.start()

    
# Start Chrome browser
driver = webdriver.Chrome(service=service)

# Check the return code
if process.poll() is None:
    print("ChromeDriver service started successfully")
else:
    print("ChromeDriver service failed to start")
time.sleep(3)

# Wait for page to load
############
driver.maximize_window()
driver.get("https://www.google.com.tw/maps")

element = driver.find_element(By.ID, "searchboxinput")
# 傳入字串
element.send_keys(store_name)
element.send_keys(Keys.ENTER)
time.sleep(3)

element = driver.find_element(By.CLASS_NAME, "hfpxzc")
print(element)

element = driver.find_element(By.XPATH, '//*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[1]/div/a')
element.send_keys(Keys.ENTER)
time.sleep(2)


element = driver.find_element(By.CLASS_NAME, "DkEaL")
element.click()
time.sleep(2)
category_click = driver.find_elements(By.CLASS_NAME, "GMtm7c.fontTitleSmall")[1]
category_click.click()
category_click = driver.find_elements(By.CLASS_NAME, "fxNQSd")[1]
category_click.click()
time.sleep(3)
for i in range(1, 12):
    pane = driver.find_element(By.CLASS_NAME, 'm6QErb.DxyBCb.kA9KIf.dS8AEf')
    driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", pane)
    time.sleep(1)
soup = BeautifulSoup(driver.page_source, "html")
for i in range(1, len(driver.find_elements(By.CLASS_NAME, "wiI7pd"))+1):
    print(driver.find_elements(By.CLASS_NAME, "wiI7pd")[i].text)
driver.close()
driver.close()
# Out:
# ...
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /tmp/ipykernel_20753/2096678622.py in <cell line: 25>()
#      23
#      24 # Start Chrome browser
# ---> 25 driver = webdriver.Chrome(service=service)
#      26
#      27 # Check the return code
#
# ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      79             service = Service(executable_path, port, service_args, service_log_path)
#      80
# ---> 81         super().__init__(
#      82             DesiredCapabilities.CHROME["browserName"],
#      83             "goog",
#
# ...

# %%
print(soup.prettify())
# Out:
# <html itemscope="" itemtype="http://schema.org/Place" jstcache="0" lang="zh-TW" style='font-family: Roboto, "Noto Sans TC", Arial, sans-serif;'>
#  <head>
#   <link href="/maps/preview/opensearch.xml?hl=zh-TW" rel="search" title="Google 地圖" type="application/opensearchdescription+xml"/>
#   <title>
#    鴨肉許(許二姊) - Google 地圖
#   </title>
#   <meta content="利用「Google 地圖」尋找本地商家、檢視地圖或規劃行車路線。" name="Description"/>
#   <meta content="initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="notranslate" name="google"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="ByHT0GXztW_RcGxS0o86DBf1WtNu02FfqlcT8njnSqU" name="google-site-verification"/>
#   <meta content="Diln__r3p9-tt39P2Cl2Amvx6oFB4PATnxuFBaw6ej8" name="google-site-verification"/>
#   <meta content="Google Maps" itemprop="name"/>
#   <meta content="Google Maps" property="og:title"/>
# ...
